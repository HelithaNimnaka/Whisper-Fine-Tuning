# %%
"""import torch
import torchaudio
from transformers import (
    WhisperProcessor,
    WhisperForConditionalGeneration,
    BitsAndBytesConfig
)
from peft import PeftModel
from redlines import Redlines

# === Config ===
base_model_name = "openai/whisper-large-v2"
adapter_checkpoint = "/mnt/sda1/FYP_2024/Helitha/DatasetsZ/asr_sinhala/Whisper-Fine-Tuning/temp2/checkpoint-3000"
audio_file = "/mnt/sda1/FYP_2024/Helitha/DatasetsZ/asr_sinhala/Whisper-Fine-Tuning/Kiri_Weherata_Mal_Neluwata_Shashika_Nisansala_Sarigama_lk [vocals] (mp3cut.net).mp3"

# === Load Processor ===
print("🔧 Loading processor...")
processor = WhisperProcessor.from_pretrained(base_model_name)

# === Load Base Model (No Adapter) ===
print("🧠 Loading *pure* base model (8-bit)...")
bnb_config = BitsAndBytesConfig(load_in_8bit=True)

base_model = WhisperForConditionalGeneration.from_pretrained(
    base_model_name,
    device_map="auto",
    quantization_config=bnb_config
)
base_model.config.forced_decoder_ids = None
base_model.eval()

# === Load Another Base Model for Fine-Tuning ===
print("🧪 Preparing second model instance for fine-tuning...")
adapter_base_model = WhisperForConditionalGeneration.from_pretrained(
    base_model_name,
    device_map="auto",
    quantization_config=bnb_config
)
adapter_base_model.config.forced_decoder_ids = None
adapter_base_model.eval()

print("🔌 Loading LoRA adapter into second model...")
fine_tuned_model = PeftModel.from_pretrained(adapter_base_model, adapter_checkpoint)
fine_tuned_model.config.forced_decoder_ids = None
fine_tuned_model.eval()

# === Transcription Function ===
def transcribe(model, audio_path, chunk_duration=15):
    import numpy as np
    import torch.nn.functional as F

    waveform, sr = torchaudio.load(audio_path)

    # Resample to 16kHz if needed
    if sr != 16000:
        waveform = torchaudio.transforms.Resample(sr, 16000)(waveform)

    # Convert to mono
    if waveform.shape[0] > 1:
        waveform = waveform.mean(dim=0, keepdim=True)

    total_samples = waveform.shape[1]
    chunk_samples = chunk_duration * 16000
    overlap = 5 * 16000  # 5-second overlap
    padding = 1 * 16000  # 1-second silence padding

    # Set decoder prompt (language & task)
    forced_decoder_ids = processor.get_decoder_prompt_ids(language="si", task="transcribe")
    model.config.forced_decoder_ids = forced_decoder_ids

    all_text = []

    for start in range(0, total_samples, chunk_samples - overlap):
        end = min(start + chunk_samples, total_samples)
        chunk = waveform[:, start:end]

        # Add 1s padding to both ends
        chunk = F.pad(chunk, (padding, padding))

        # Extract input features
        input_features = processor.feature_extractor(
            chunk.squeeze().numpy(), sampling_rate=16000, return_tensors="pt"
        ).input_features.to(model.device)

        # Match model precision
        if model.dtype == torch.float16:
            input_features = input_features.to(dtype=torch.float16)

        attention_mask = torch.ones(input_features.shape[:2], dtype=torch.long).to(model.device)

        with torch.no_grad():
            predicted_ids = model.generate(
                input_features,
                attention_mask=attention_mask,
                language="si",
                task="transcribe",
                max_length=448,
                do_sample=False,
                num_beams=5,
                no_repeat_ngram_size=4,
                early_stopping=True
            )

        text = processor.tokenizer.batch_decode(predicted_ids, skip_special_tokens=True)[0]
        all_text.append(text.strip())

    return " ".join(all_text)

# === Main Execution ===
if __name__ == "__main__":
    print("🎧 Transcribing with base model...")
    base_output = transcribe(base_model, audio_file)

    print("🧪 Transcribing with fine-tuned model...")
    tuned_output = transcribe(fine_tuned_model, audio_file)

    print("\n📝 Base Model Output:\n", base_output)
    print(f"Length of base model output: {len(base_output)} characters\n")

    print("\n📝 Fine-Tuned Model Output:\n", tuned_output)
    print(f"Length of fine-tuned model output: {len(tuned_output)} characters\n")

    print("\n📊 Comparing with Redlines...")
    diff = Redlines(base_output, tuned_output)
    #print(diff.output_markdown)
    from IPython.display import Markdown, display
    display(Markdown(diff.output_markdown))"""
# Out:
# 'import torch\nimport torchaudio\nfrom transformers import (\n    WhisperProcessor,\n    WhisperForConditionalGeneration,\n    BitsAndBytesConfig\n)\nfrom peft import PeftModel\nfrom redlines import Redlines\n\n# === Config ===\nbase_model_name = "openai/whisper-large-v2"\nadapter_checkpoint = "/mnt/sda1/FYP_2024/Helitha/DatasetsZ/asr_sinhala/Whisper-Fine-Tuning/temp2/checkpoint-3000"\naudio_file = "/mnt/sda1/FYP_2024/Helitha/DatasetsZ/asr_sinhala/Whisper-Fine-Tuning/Kiri_Weherata_Mal_Neluwata_Shashika_Nisansala_Sarigama_lk [vocals] (mp3cut.net).mp3"\n\n# === Load Processor ===\nprint("🔧 Loading processor...")\nprocessor = WhisperProcessor.from_pretrained(base_model_name)\n\n# === Load Base Model (No Adapter) ===\nprint("🧠 Loading *pure* base model (8-bit)...")\nbnb_config = BitsAndBytesConfig(load_in_8bit=True)\n\nbase_model = WhisperForConditionalGeneration.from_pretrained(\n    base_model_name,\n    device_map="auto",\n    quantization_config=bnb_config\n)\nbase_model.config.force
# ...

# %% [markdown]
# # Clearing cache

# %%
"""!ls ~/.cache/whisper
# !du -sh ~/.cache/whisper
# !rm -rf ~/.cache/whisper"""
# Out:
# '!ls ~/.cache/whisper\n!du -sh ~/.cache/whisper\n!rm -rf ~/.cache/whisper'

# %%
import os
import torch
import torchaudio
import torch.nn.functional as F
import webrtcvad
from transformers import (
    WhisperProcessor,
    WhisperForConditionalGeneration,
    BitsAndBytesConfig
)
from peft import PeftModel
from redlines import Redlines
import subprocess

# Optional toggles
USE_DEMUCS = True
USE_VAD = True

# === Config ===
base_model_name   = "openai/whisper-large-v2"
adapter_checkpoint = "/mnt/sda1/FYP_2024/Helitha/DatasetsZ/asr_sinhala/Whisper-Fine-Tuning/temp2/checkpoint-3000"
audio_file        = "/mnt/sda1/FYP_2024/Helitha/DatasetsZ/asr_sinhala/RHEWC2BB.mp3"

# === Load Processor ===
print("🔧 Loading processor...")
processor = WhisperProcessor.from_pretrained(base_model_name)

# === Load Base Model (8-bit) ===
print("🧠 Loading base model in 8-bit...")
bnb_config = BitsAndBytesConfig(load_in_8bit=True)
base_model = WhisperForConditionalGeneration.from_pretrained(
    base_model_name,
    device_map="auto",
    quantization_config=bnb_config
)
base_model.config.forced_decoder_ids = None
base_model.eval()

# === Load Fine-Tuned Model ===
print("🔌 Loading fine-tuned LoRA adapter...")
adapter_base_model = WhisperForConditionalGeneration.from_pretrained(
    base_model_name,
    device_map="auto",
    quantization_config=bnb_config
)
adapter_base_model.config.forced_decoder_ids = None
adapter_base_model.eval()
fine_tuned_model = PeftModel.from_pretrained(adapter_base_model, adapter_checkpoint)
fine_tuned_model.config.forced_decoder_ids = None
fine_tuned_model.eval()

# === Vocal Separation using Demucs (Optional) ===
def separate_vocals(input_path):
    out_dir = "demucs_output"
    os.makedirs(out_dir, exist_ok=True)
    print("🎤 Separating vocals with Demucs...")
    subprocess.run([
        "demucs", "--two-stems=vocals",
        "-o", out_dir, input_path
    ], check=True)
    stem_dir = os.path.join(out_dir, "htdemucs",
                            os.path.splitext(os.path.basename(input_path))[0])
    return os.path.join(stem_dir, "vocals.wav")

# === VAD via WebRTC ===
def apply_vad(audio_tensor, sample_rate):
    """Return only the voiced segments as one concatenated tensor."""
    print("🧼 Applying WebRTC VAD...")
    vad = webrtcvad.Vad(3)  # aggressiveness: 0–3
    
    # mono numpy array in int16 PCM
    wav = audio_tensor.squeeze(0)  # [samples]
    if sample_rate != 16000:
        raise ValueError("VAD only supports 16000 Hz in this implementation")
    pcm = (wav.cpu().numpy() * 32768).astype("int16").tobytes()
    
    frame_duration_ms = 30
    frame_sample_count = int(sample_rate * frame_duration_ms / 1000)
    frame_byte_count = frame_sample_count * 2  # 2 bytes per int16 sample
    
    # slice into 30ms frames
    frames = [
        pcm[i : i + frame_byte_count]
        for i in range(0, len(pcm), frame_byte_count)
        if len(pcm[i : i + frame_byte_count]) == frame_byte_count
    ]
    
    # detect speech frames
    speech_frames = [i for i, f in enumerate(frames)
                     if vad.is_speech(f, sample_rate)]
    
    # group consecutive frames into segments
    segments = []
    if speech_frames:
        start = speech_frames[0]
        prev = start
        for idx in speech_frames[1:]:
            if idx == prev + 1:
                prev = idx
            else:
                segments.append((start, prev))
                start = idx
                prev = idx
        segments.append((start, prev))
    
    # reconstruct audio tensor
    voiced_chunks = []
    for (s, e) in segments:
        s_sample = s * frame_sample_count
        e_sample = (e + 1) * frame_sample_count
        voiced_chunks.append(audio_tensor[:, s_sample:e_sample])
    
    if not voiced_chunks:
        print("⚠️ No speech detected, returning 1-silence chunk.")
        return torch.zeros(1, sample_rate)
    
    return torch.cat(voiced_chunks, dim=1)

# === Transcription with chunking ===
def transcribe(model, audio_path, chunk_duration=30):
    # load & preprocess
    waveform, sr = torchaudio.load(audio_path)
    if sr != 16000:
        waveform = torchaudio.transforms.Resample(sr, 16000)(waveform)
    if waveform.size(0) > 1:
        waveform = waveform.mean(dim=0, keepdim=True)
    if USE_VAD:
        waveform = apply_vad(waveform, 16000)
    
    total_samples = waveform.size(1)
    chunk_samples = chunk_duration * 16000
    overlap      = 5 * 16000
    padding      = 1 * 16000
    
    # force Sinhala‐transcribe prompt
    forced_decoder_ids = processor.get_decoder_prompt_ids(
        language="si", task="transcribe"
    )
    model.config.forced_decoder_ids = forced_decoder_ids
    
    texts = []
    for start in range(0, total_samples, chunk_samples - overlap):
        end = min(start + chunk_samples, total_samples)
        chunk = waveform[:, start:end]
        chunk = F.pad(chunk, (padding, padding))
        
        feats = processor.feature_extractor(
            chunk.squeeze().numpy(),
            sampling_rate=16000,
            return_tensors="pt"
        ).input_features.to(model.device)
        if model.dtype == torch.float16:
            feats = feats.to(dtype=torch.float16)
        mask = torch.ones(feats.shape[:2], dtype=torch.long).to(model.device)
        
        with torch.no_grad():
            preds = model.generate(
                feats,
                attention_mask=mask,
                max_length=448,
                num_beams=5,
                no_repeat_ngram_size=4,
                early_stopping=True
            )
        txt = processor.tokenizer.batch_decode(preds, skip_special_tokens=True)[0]
        texts.append(txt.strip())
    
    return " ".join(texts)

# === Main ===
if __name__ == "__main__":
    if USE_DEMUCS:
        audio_file = separate_vocals(audio_file)
    
    print("🎧 Transcribing with base model...")
    base_out = transcribe(base_model, audio_file)
    
    print("🧪 Transcribing with fine-tuned model...")
    tuned_out = transcribe(fine_tuned_model, audio_file)
    
    print("\n📝 Base Model Output:\n", base_out)
    print(f"(Length: {len(base_out)} characters)\n")
    
    print("📝 Fine-Tuned Model Output:\n", tuned_out)
    print(f"(Length: {len(tuned_out)} characters)\n")
    
    print("📊 Diff:\n")
    diff = Redlines(base_out, tuned_out)
    from IPython.display import Markdown, display
    display(Markdown(diff.output_markdown))

    #delete demucs output
    if USE_DEMUCS:
        subprocess.run(["rm", "-rf", "demucs_output"])
    #delete whisper cache
    subprocess.run(["rm", "-rf", "~/.cache/whisper"])
# Out:
# 🔧 Loading processor...
# 🧠 Loading base model in 8-bit...
# Could not load bitsandbytes native library: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.34' not found (required by /home/fyp2selfdriving/anaconda3/envs/textz/lib/python3.9/site-packages/bitsandbytes/libbitsandbytes_cuda126.so)
# Traceback (most recent call last):
#   File "/home/fyp2selfdriving/anaconda3/envs/textz/lib/python3.9/site-packages/bitsandbytes/cextension.py", line 85, in <module>
#     lib = get_native_library()
#   File "/home/fyp2selfdriving/anaconda3/envs/textz/lib/python3.9/site-packages/bitsandbytes/cextension.py", line 72, in get_native_library
#     dll = ct.cdll.LoadLibrary(str(binary_path))
#   File "/home/fyp2selfdriving/anaconda3/envs/textz/lib/python3.9/ctypes/__init__.py", line 460, in LoadLibrary
#     return self._dlltype(name)
#   File "/home/fyp2selfdriving/anaconda3/envs/textz/lib/python3.9/ctypes/__init__.py", line 382, in __init__
#     self._handle = _dlopen(self._name, mode)
# ...
